# %%
import pandas as pd

# %%
dict = {'name':['usaid' , 'ahmed'], 'age':['20' , '35']}
df = pd.DataFrame(dict) # dictionary send to dataframes. we also send the csv files to dataFrames

# %%
df1 = pd.read_csv('Student_Performance.csv') # to read the data of csv file we use this method
# type(df1) # Data Frames
# Out:
# pandas.core.frame.DataFrame

# %%
# df2 = pd.read_excel('excel.xlsx' , sheet_name= 'specific file name')
df1
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df1['Sleep Hours'] # Specific Column. and also deals that column as a series
type(df1['Sleep Hours'])
# Out:
# pandas.core.series.Series

# %%
df1[['Previous Scores' , 'Performance Index']]
type(df1[['Previous Scores' , 'Performance Index']])
df1[['Previous Scores' , 'Performance Index']]
# Out:
#       Previous Scores  Performance Index
# 0                  99                 91
# 1                  82                 65
# 2                  51                 45
# 3                  52                 36
# 4                  75                 66
# ...               ...                ...
# 9995               49                 23
# 9996               64                 58
# 9997               83                 74
# 9998               97                 95
# 9999               74                 64
#
# [10000 rows x 2 columns]

# %%
df1['Previous Scores'] = '59'
df1
# Out:
#       Hours Studied Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7              59                        Yes            9
# 1                 4              59                         No            4
# 2                 8              59                        Yes            7
# 3                 5              59                        Yes            5
# 4                 7              59                         No            8
# ...             ...             ...                        ...          ...
# 9995              1              59                        Yes            4
# 9996              7              59                        Yes            8
# 9997              6              59                        Yes            8
# 9998              9              59                        Yes            7
# 9999              7              59                         No            8
#
# ...

# %%
df1['Sample Question Papers Practiced for final'] = 7 # New Column added
df1
# Out:
#       Hours Studied Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7              59                        Yes            9
# 1                 4              59                         No            4
# 2                 8              59                        Yes            7
# 3                 5              59                        Yes            5
# 4                 7              59                         No            8
# ...             ...             ...                        ...          ...
# 9995              1              59                        Yes            4
# 9996              7              59                        Yes            8
# 9997              6              59                        Yes            8
# 9998              9              59                        Yes            7
# 9999              7              59                         No            8
#
# ...

# %%
df1['Sample Question Papers Practiced for final'] = [1 if(pfIndex >= 90) else 5 if(pfIndex > 70 and pfIndex < 90) else 7 for pfIndex in df1['Performance Index']]
# we make Conditional column on the basis of performance Index column
df1
# Out:
#       Hours Studied Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7              59                        Yes            9
# 1                 4              59                         No            4
# 2                 8              59                        Yes            7
# 3                 5              59                        Yes            5
# 4                 7              59                         No            8
# ...             ...             ...                        ...          ...
# 9995              1              59                        Yes            4
# 9996              7              59                        Yes            8
# 9997              6              59                        Yes            8
# 9998              9              59                        Yes            7
# 9999              7              59                         No            8
#
# ...
